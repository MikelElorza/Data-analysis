# %%
from snAPI.Main import *
import matplotlib.pyplot as plt
import os
import pandas as pd
from HH import HH_T3
from Functions import *

# %%
sn=snAPI()

# %%
free_0='C:/Users/Mikel/Documents/Data analysis/Narrow field/Data/APD/ZFFL51_ANN265.2/Filter0/default.ptu'
free_3='C:/Users/Mikel/Documents/Data analysis/Narrow field/Data/APD/ZFFL51_ANN265.2/Filter3/default.ptu'
free_7='C:/Users/Mikel/Documents/Data analysis/Narrow field/Data/APD/ZFFL51_ANN265.2/Filter7/default.ptu'
free_6='C:/Users/Mikel/Documents/Data analysis/Narrow field/Data/APD/ZFFL51_ANN265.2/Filter6/default.ptu'
free_8='C:/Users/Mikel/Documents/Data analysis/Narrow field/Data/APD/ZFFL51_ANN265.2/Filter8/default.ptu'

ba_0='C:/Users/Mikel/Documents/Data analysis/Narrow field/Data/APD/ZFFL51_ANN265 _Ba.2/Filter0/default.ptu'
ba_3='C:/Users/Mikel/Documents/Data analysis/Narrow field/Data/APD/ZFFL51_ANN265 _Ba.2/Filter3/default.ptu'
ba_7='C:/Users/Mikel/Documents/Data analysis/Narrow field/Data/APD/ZFFL51_ANN265 _Ba.2/Filter7/default.ptu'
ba_6='C:/Users/Mikel/Documents/Data analysis/Narrow field/Data/APD/ZFFL51_ANN265 _Ba.2/Filter6/default.ptu'
ba_8='C:/Users/Mikel/Documents/Data analysis/Narrow field/Data/APD/ZFFL51_ANN265 _Ba.2/Filter8/default.ptu'

# %%
f0=HH_T3(sn,filename=free_0)
f3=HH_T3(sn,filename=free_3)
f7=HH_T3(sn,filename=free_7)
f6=HH_T3(sn,filename=free_6)
f8=HH_T3(sn,filename=free_8)
##
ba0=HH_T3(sn,filename=ba_0)
ba3=HH_T3(sn,filename=ba_3)
ba7=HH_T3(sn,filename=ba_7)
ba6=HH_T3(sn,filename=ba_6)
ba8=HH_T3(sn,filename=ba_8)

# %% [markdown]
# # Free molecule

# %%
binning=20
countsf0,edges=binned(f0.df['dTimes'],f0.t_resol*binning,0,8000)
countsf3,edges=binned(f3.df['dTimes'],f3.t_resol*binning,0,8000)
countsf6,edges=binned(f6.df['dTimes'],f6.t_resol*binning,0,8000)
countsf8,edges=binned(f8.df['dTimes'],f8.t_resol*binning,0,8000)
countsf7,edges=binned(f7.df['dTimes'],f7.t_resol*binning,0,8000)
bins=edges2bins(edges)

fig,ax=plt.subplots(1,2,figsize=(10,4))

ax[0].plot(bins,countsf0,label='Free (no filters)')
ax[0].plot(bins,countsf3,label='Free (filter 3)')
ax[0].plot(bins,countsf6,label='Free (filter 6)')
ax[0].plot(bins,countsf8,label='Free (filter 8)')
ax[0].set_yscale('log')
ax[0].set_xlabel('Time ($ns$)')
ax[0].set_ylabel('Counts')

ax[1].plot(bins,countsf0,label='Free (no filters)')
ax[1].plot(bins,countsf3,label='Free (filter 3)')
ax[1].plot(bins,countsf7,label='Free (filter 7)')
ax[1].plot(bins,countsf6,label='Free (filter 6)')
ax[1].plot(bins,countsf8,label='Free (filter 8)')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[1].set_xlabel('Time ($ns$)')
ax[1].set_ylabel('Counts')
ax[0].legend()
#plt.savefig('Lifetimes_free.png')

# %% [markdown]
# # Chelated molecule

# %%
binning=20
countsba0,edges=binned(ba0.df['dTimes'],ba0.t_resol*binning,0,8000)
countsba3,edges=binned(ba3.df['dTimes'],ba3.t_resol*binning,0,8000)
countsba6,edges=binned(ba6.df['dTimes'],ba6.t_resol*binning,0,8000)
countsba8,edges=binned(ba8.df['dTimes'],ba8.t_resol*binning,0,8000)
countsba7,edges=binned(ba7.df['dTimes'],ba7.t_resol*binning,0,8000)
bins=edges2bins(edges)

fig,ax=plt.subplots(1,2,figsize=(10,4))

ax[0].plot(bins,countsba0,label='Ba (no filters)')
ax[0].plot(bins,countsba3,label='Ba (filter 3)')
ax[0].plot(bins,countsba7,label='Ba (filter 7)')
ax[0].plot(bins,countsba6,label='Ba (filter 6)')
ax[0].plot(bins,countsba8,label='Ba (filter 8)')
ax[0].set_yscale('log')
ax[0].set_xlabel('Time ($ns$)')
ax[0].set_ylabel('Counts')

ax[1].plot(bins,countsba0,label='Ba (no filters)')
ax[1].plot(bins,countsba3,label='Ba (filter 3)')
ax[1].plot(bins,countsba7,label='Ba (filter 7)')
ax[1].plot(bins,countsba6,label='Ba (filter 6)')
ax[1].plot(bins,countsba8,label='Ba (filter 8)')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[1].set_xlabel('Time ($ns$)')
ax[1].set_ylabel('Counts')
ax[0].legend()
#plt.savefig('Lifetimes_ba.png')

# %% [markdown]
# # Comparison free/chelated

# %% [markdown]
# ## By filter

# %% [markdown]
# ### No filter

# %%
binning=20
countsf0,edges=binned(f0.df['dTimes'],f0.t_resol*binning,0,8000)
countsba0,edges=binned(ba0.df['dTimes'],ba0.t_resol*binning,0,8000)
bins=edges2bins(edges)
cumulf0=cumulative(countsf0)
cumulba0=cumulative(countsba0)

# %%
fig,ax=plt.subplots(1,2,figsize=(10,4))
ax[0].plot(bins,countsf0,label='Free (no filters)')
ax[0].plot(bins,countsba0,label='Chelated (no filters)')
ax[0].set_yscale('log')
ax[0].set_xlabel('Time ($ns$)')
ax[0].set_ylabel('Counts')

ax[1].plot(bins,countsf0,label='Free (no filters)')
ax[1].plot(bins,countsba0,label='Chelated (no filters)')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[1].set_xlabel('Time ($ns$)')
ax[1].set_ylabel('Counts')
ax[0].legend()
ax[1].legend()

#plt.savefig('Filter0.png')

# %%
plt.plot(bins,cumulba0/cumulf0)

# %% [markdown]
# ### Filter 7

# %%
binning=20
countsf7,edges=binned(f7.df['dTimes'],f7.t_resol*binning,0,8000)
countsba7,edges=binned(ba7.df['dTimes'],ba7.t_resol*binning,0,8000)
bins=edges2bins(edges)
cumulf7=cumulative(countsf7)
cumulba7=cumulative(countsba7)

# %%
fig,ax=plt.subplots(1,2,figsize=(10,4))
ax[0].plot(bins,countsf7,label='Free (filter 7)')
ax[0].plot(bins,countsba7,label='Chelated (filter 7)')
ax[0].set_yscale('log')
ax[0].set_xlabel('Time ($ns$)')
ax[0].set_ylabel('Counts')

ax[1].plot(bins,countsf7,label='Free (filter 7)')
ax[1].plot(bins,countsba7,label='Chelated (filter 7)')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[1].set_xlabel('Time ($ns$)')
ax[1].set_ylabel('Counts')
ax[0].legend()
ax[1].legend()
#plt.savefig('Filter7.png')

# %%
plt.plot(bins[0:-50],(cumulba7/cumulf7)[0:-50])

# %% [markdown]
# ### Filter 6

# %%
binning=20
countsf6,edges=binned(f6.df['dTimes'],f6.t_resol*binning,0,8000)
countsba6,edges=binned(ba6.df['dTimes'],ba6.t_resol*binning,0,8000)
bins=edges2bins(edges)
cumulf6=cumulative(countsf6)
cumulba6=cumulative(countsba6)

# %%
fig,ax=plt.subplots(1,2,figsize=(10,4))
ax[0].plot(bins,countsf6,label='Free (filter 6)')
ax[0].plot(bins,countsba6,label='Chelated (filter 6)')
ax[0].set_yscale('log')
ax[0].set_xlabel('Time ($ns$)')
ax[0].set_ylabel('Counts')

ax[1].plot(bins,countsf6,label='Free (filter 6)')
ax[1].plot(bins,countsba6,label='Chelated (filter 6)')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[1].set_xlabel('Time ($ns$)')
ax[1].set_ylabel('Counts')
ax[0].legend()
ax[1].legend()
#plt.savefig('Filter6.png')

# %%
plt.plot(bins[0:-50],(cumulba6/cumulf6)[0:-50])

# %% [markdown]
# ### Filter 8

# %%
binning=20
countsf8,edges=binned(f8.df['dTimes'],f8.t_resol*binning,0,8000)
countsba8,edges=binned(ba8.df['dTimes'],ba8.t_resol*binning,0,8000)
bins=edges2bins(edges)
cumulf8=cumulative(countsf8)
cumulba8=cumulative(countsba8)

# %%
fig,ax=plt.subplots(1,2,figsize=(10,4))
ax[0].plot(bins,countsf8,label='Free (filter 8)')
ax[0].plot(bins,countsba8,label='Chelated (filter 8)')
ax[0].set_yscale('log')
ax[0].set_xlabel('Time ($ns$)')
ax[0].set_ylabel('Counts')

ax[1].plot(bins,countsf8,label='Free (filter 8)')
ax[1].plot(bins,countsba8,label='Chelated (filter 8)')
ax[1].set_yscale('log')
ax[1].set_xscale('log')
ax[1].set_xlabel('Time ($ns$)')
ax[1].set_ylabel('Counts')
ax[0].legend()
ax[1].legend()
#plt.savefig('Filter8.png')

# %%
plt.plot(bins[0:-50],(cumulba8/cumulf8)[0:-50])
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_2764\3359768229.py:1: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(bins[0:-50],(cumulba8/cumulf8)[0:-50])

# %%
plt.plot(bins[0:-10],(cumulba0/cumulf0)[0:-10],label='No filter')
plt.plot(bins[0:-10],(cumulba6/cumulf6)[0:-10],label='Filter 6')
plt.plot(bins[0:-10],(cumulba7/cumulf7)[0:-10],label='Filter 7')
plt.plot(bins[0:-10],(cumulba8/cumulf8)[0:-10],label='Filter 8')
plt.xlabel('Time gate (ns)')
plt.ylabel('$\int_{T_0}^{T_f} Counts(Ba)/Counts(Free)$')
plt.legend()
#plt.savefig('Discr.png')
# Out:
# C:\Users\Mikel\AppData\Local\Temp\ipykernel_2764\3135858194.py:4: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(bins[0:-10],(cumulba8/cumulf8)[0:-10],label='Filter 8')

# %% [markdown]
# # Separation 2D

# %%
c2df=cumulative2D(countsf0)
c2dba=cumulative2D(countsba0)

# %%
plt.imshow(c2dba/c2df,extent=[bins[0],bins[-1],bins[-1],bins[0]],vmin=None, vmax=50)
plt.contour(bins,bins,c2dba/c2df,np.arange(0,55,5),cmap='plasma')
plt.xlabel('$T_f$(ns)')
plt.ylabel('$T_0$(ns)')
# Out:
# Text(0, 0.5, '$T_0$(ns)')
