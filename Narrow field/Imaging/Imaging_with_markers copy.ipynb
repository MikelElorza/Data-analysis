# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
from snAPI.Main import *
import pandas as pd
sys.path.append("../")
from HH import HH_T3
from Functions import *
import time

# %%
filename='../../../Acquisition2/Data/Trial_markers/T/PTU_4.ptu' # Path to the PTU file

# %%
sn=snAPI()
sn.getDevice()
sn.getFileDevice(filename)
sn.initDevice(MeasMode.T3)
# Out:
# True

# %%
sn.raw.measure()
data = sn.raw.getData()

# %%
markers_Bool=np.array([sn.raw.isMarker(datai) for datai in data])

# %%
plt.plot(markers_Bool,linewidth=1)

# %%
plt.plot(markers_Bool*sn.raw.markers(data)[0])

# %%
markers_Bool
# Out:
# array([False, False, False, ..., False, False, False])
