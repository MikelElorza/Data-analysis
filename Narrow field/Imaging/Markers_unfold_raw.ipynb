# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from snAPI.Main import *

# %%
filename='../../../Acquisition2/Data/Trial_markers/T/PTU_6.ptu'

# %%
sn=snAPI()
sn.getDevice()
sn.getFileDevice(filename)
sn.initDevice(MeasMode.T3)
# Out:
# True

# %%
sn.unfold.measure()
times, channels = sn.unfold.getData()
markers_Bool=np.array([sn.unfold.isMarker(datai) for datai in channels])
m1=markers_Bool*sn.unfold.markers(channels)[1]
m2=markers_Bool*sn.unfold.markers(channels)[2]
plt.plot(m1)
plt.plot(m2)

# %%
sn.raw.measure()
data = sn.raw.getData()
markers_Bool=np.array([sn.raw.isMarker(datai) for datai in data])
m1=markers_Bool*sn.raw.markers(data)[1]
m2=markers_Bool*sn.raw.markers(data)[2]
plt.plot(m1)
plt.plot(m2)
